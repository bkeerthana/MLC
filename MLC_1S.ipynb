# %% [markdown]
# Recap
#
# - Machine learning for cybersecurity
# - Applications of Machine learning
# - Cyber
# - Security
# - Cybersecurity
# - Application of Machine learning in cyberecurity

# %% [markdown]
# Unit-1: DATA ANALYTICS

# %% [markdown]
# Data

# %% [markdown]
# Information

# %% [markdown]
# Data  -- Analytics-- Information

# %% [markdown]
# Data Vs Information

# %% [markdown]
# Activity:  Data Vs Information
#
#     * If server records 10,000 login attempts in one hour
#
#     * The average failed logins is more than 78 percentage
#
#     * .pcap file containing packet headers (source IP, destination IP, protocol, packet size) captured from a network interface.
#
#     * IP address 192.168.1.25 generated 120 failed login attempts within 5 minutes
#
#     * A table showing: Flow ID , Average packet size , Flow duration , Packet count
#
#     * Possible brute-force attack detected from IP 10.0.0.5

# %% [markdown]
# Activity : context
#
#         Two analysts examine the same firewall log file:
#                 Analyst A reports “High number of failed logins”
#                 Analyst B reports “Credential-stuffing attack pattern”
#
#         How can the same data lead to different information or knowledge?

# %% [markdown]
# Analytics -Process
# Ex:
#  - correlation
#  - comparision

# %% [markdown]
# Activity: Data or Information

# %% [markdown]
# | Time (sec) | Src IP   | Packets/sec | Protocol |
# | ---------- | -------- | ----------- | -------- |
# | 1          | 10.0.0.5 | 120         | TCP      |
# | 2          | 10.0.0.5 | 130         | TCP      |
# | 3          | 10.0.0.5 | 850         | TCP      |
# | 4          | 10.0.0.5 | 920         | TCP      |
# | 5          | 10.0.0.5 | 910         | TCP      |

# %% [markdown]
# Activity: convert this Data to information

# %% [markdown]
# Steps to convert Data to Information
# Data ---> Ask Question ---> process ---> Information

# %% [markdown]
# Activity : Ask Questions

# %% [markdown]
# Activity: Process (Manually)

# %% [markdown]
# Activity: Information (the result of the process)

# %% [markdown]
# Activity: Interpretation (understanding of information)

# %% [markdown]
# Activity: Knowledge (validating the interpretation)

# %% [markdown]
# Activity: Decision (Taking action on Knowledge)

# %% [markdown]
# Activity:
#
# | Timestamp | Username | Login Attempts | Result |
# | --------- | -------- | -------------- | ------ |
# | 10:01     | admin    | 1              | Fail   |
# | 10:02     | admin    | 1              | Fail   |
# | 10:03     | admin    | 1              | Fail   |
# | 10:04     | admin    | 1              | Fail   |
# | 10:05     | admin    | 1              | Fail   |

# %% [markdown]
# question
# information
# interpretation
# knowledge
# decision

# %% [markdown]
# Analysis

# %% [markdown]
# Types of Analytics
#
#       - Descriptive Analytics
#         Explaining behavior
#
#       - Diagnostic
#         Identifying patterns and trends
#
#       - predictive
#         Predicting outcomes
#
#       - Prescriptive
#         Recommending actions

# %% [markdown]
# Activity

# %% [markdown]
# Student Marks

# %% [markdown]
# | Student_ID | Attendance_% | Quiz_Avg | Assignment_Avg | Final_Mark |
# | ---------- | ------------ | -------- | -------------- | ---------- |
# | S1         | 92           | 78       | 85             | 82         |
# | S2         | 65           | 60       | 58             | 55         |
# | S3         | 88           | 82       | 80             | 84         |
# | S4         | 70           | 68       | 72             | 69         |
# | S5         | 95           | 90       | 92             | 91         |

# %% [markdown]
# Web page traffic

# %% [markdown]
# | Day | Visitors | Page_Views | Bounce_Rate_% | Sales |
# | --- | -------- | ---------- | ------------- | ----- |
# | Mon | 120      | 300        | 55            | 8     |
# | Tue | 150      | 420        | 48            | 12    |
# | Wed | 100      | 260        | 60            | 6     |
# | Thu | 180      | 500        | 45            | 15    |
# | Fri | 200      | 620        | 40            | 18    |

# %% [markdown]
# Spam Email detection
#
# | Email_ID | Sender_Domain   | Subject_Length | Contains_Link | Contains_Attachment | Spam_Keywords_Count | Email_Label |
# | -------- | --------------- | -------------- | ------------- | ------------------- | ------------------- | ----------- |
# | E1       | gmail.com       | 18             | No            | No                  | 0                   | Legit       |
# | E2       | win-prize.net   | 45             | Yes           | No                  | 5                   | Spam        |
# | E3       | bank-alerts.co  | 52             | Yes           | Yes                 | 6                   | Spam        |
# | E4       | company.org     | 25             | No            | Yes                 | 1                   | Legit       |
# | E5       | free-offers.biz | 60             | Yes           | No                  | 7                   | Spam        |

# %% [markdown]
# Stages of DataAnalytics
#
#
#     Problem Definition
#     Data Collection
#     Data Cleaning
#     Exploratory Data Analysis
#     Data Modeling
#     Data Visualization
#     Decision Making

# %% [markdown]
# Next ....

# %% [markdown]
# Types of Data
#
#     - structure
#     - state
#     - source
#     - security relavance
#     - value
#     - time
