# %%
# import pandas and numpy

# %% [markdown]
# ## 0. Create the dataset used for ALL questions
#
# You will create **two DataFrames** and merge them:
#
# - `df_students` (from list): `student_id, name, program, marks`
# - `df_scores` (from dict): `student_id, attendance, internal_marks`
#
# Then merge into a single DataFrame `df` on `student_id`.

# %% [markdown]
# ### Q1. Create a DataFrame using a list
# Create `df_students` from a list-of-lists. Assign columns: `student_id`, `name`, `program`, `marks`.

# %%
# TODO: Create df_students using the list below
students = [[101, 'Anu', 'Cybersecurity', 85], [102, 'Ravi', 'Cybersecurity', 72], [103, 'Meera', 'Data Science', 91], [104, 'Kiran', 'Cybersecurity', 66], [105, 'Sana', 'AI', 78], [106, 'Divya', 'Data Science', 59], [107, 'Naveen', 'Cybersecurity', 88], [108, 'Asha', 'AI', 74]]

# df_students =
# df_students.columns =

df_students

# %% [markdown]
# ### Q2. Create a DataFrame using a dictionary
# Create `df_scores` using the dictionary. Ensure numeric columns are numeric.

# %%
# TODO: Create df_scores using the dictionary below
scores = {'student_id': [101, 102, 103, 104, 105, 106, 107, 108], 'attendance': [92, 85, 98, 70, 88, 76, 95, 82], 'internal_marks': [40, 35, 45, 30, 38, 28, 44, 34]}

# df_scores = ...

df_scores

# %% [markdown]
# ### Q3. Merge the DataFrames on the common column
# Merge on `student_id`.
# 1) Inner join into `df`
# 2) Left join into `df_left`
# 3) Compare shapes and explain inner vs left.

# %%
# TODO:
# df = ...
# df_left = ...
# print(df.shape, df_left.shape)

df

# %% [markdown]
# ## 1. Data Inspection

# %% [markdown]
# ### Q4. Basic inspection
# Perform: head(3), tail(2), shape, columns, dtypes/info.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q5. Missing value inspection
# Check missing values; counts per column; affected columns.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q6. Unique value analysis
# Find nunique per column; identify categorical candidates; convert suitable columns to category.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 2. Indexing & Slicing

# %% [markdown]
# ### Q7. Column indexing
# Select: (1) single column (2) multiple columns.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q8. Row indexing
# Access rows using positional indexing and label-based indexing.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q9. Index manipulation
# Set `student_id` as index; reset back; explain use.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q10. Slicing
# Slice row ranges; slice rows+columns; last two records of a column.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 3. Filtering & Boolean Logic

# %% [markdown]
# ### Q11. Basic filtering
# Filter based on marks threshold; filter by program.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q12. Comparison operators
# Filter based on marks and attendance using comparison operators.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q13. Boolean logic (AND/OR/NOT)
# Apply compound conditions using `&`, `|`, `~` correctly.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q14. isin()
# Filter where program is in a list; student_id is in a list.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 4. Conditional Transformation

# %% [markdown]
# ### Q15. where()
# Create a masked version of marks: values failing a condition become NaN/label; explain why `where()` is useful.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q16. Derived column: grade
# Create `grade`: A(>=85), B(70–84), C(<70); count each grade.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q17. Conditional flag
# Create `eligible_for_exam` based on attendance threshold; count eligible vs not.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 5. Query-Based Filtering

# %% [markdown]
# ### Q18. query() basics
# Filter using query with multiple conditions; rewrite using boolean indexing; compare readability.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q19. Advanced query()
# Filter not in a category and numeric values in a range.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 6. Sorting & Ranking

# %% [markdown]
# ### Q20. Sorting
# Sort by marks ascending/descending; sort by multiple columns.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q21. Ranking
# Rank by marks; identify top/bottom; handle ties.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 7. Statistical Operations

# %% [markdown]
# ### Q22. Descriptive statistics
# Compute mean/median/std/min/max for key numeric columns.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q23. Cumulative & quantiles
# Compute cumsum; compute quartiles (Q1,Q2,Q3).

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q24. describe()
# Generate describe summary and interpret key measures.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 8. Distribution & Outliers

# %% [markdown]
# ### Q25. Distribution analysis
# Compute range and IQR; interpret spread.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q26. Outlier detection (IQR method)
# Identify outliers outside [Q1−1.5IQR, Q3+1.5IQR].

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 9. GroupBy Core

# %% [markdown]
# ### Q27. Single-column groupby
# Compute mean marks per program; total internal marks per program.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q28. Multiple aggregations with agg()
# Use groupby().agg() to compute count/sum/mean/max.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q29. Multi-key groupby
# Group by program + grade; compute counts or means; interpret multi-index.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 10. Advanced GroupBy Analytics

# %% [markdown]
# ### Q30. Pivot-style groupby (unstack)
# Create a matrix (program × grade) using groupby + unstack.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q31. Proportions within group
# Compute grade distribution (percent) within each program.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q32. Top-N per group
# Find top 1 and top 2 students by marks within each program.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q33. Rank within groups
# Create within-program rank based on marks.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q34. Conditional aggregation
# Count how many students in each program satisfy a condition (e.g., marks>=75 & attendance>=85).

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q35. groupby + value_counts
# Compute grade counts per program using value_counts; present as table.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 11. Time-Based GroupBy (Optional)

# %% [markdown]
# ### Q36. Time-based aggregation
# Create a synthetic datetime column and demonstrate resample/groupby by day/hour with an aggregated metric.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 12. Data Quality & Cleaning

# %% [markdown]
# ### Q37. Missing value handling
# Introduce missing values, detect, impute using mean/median; document.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q38. Data quality audit
# Check duplicates, invalid marks (<0 or >100), correct them and document changes.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 13. Normalization & Correlation

# %% [markdown]
# ### Q39. Normalization (Min–Max)
# Create min-max normalized marks column; explain why used.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q40. Correlation
# Compute correlation between attendance and marks; interpret and state limitations.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 14. Decision-Oriented Analysis

# %% [markdown]
# ### Q41. Rule-based decision
# Define a rule (scholarship/high priority) using marks and attendance; extract eligible.

# %%
# TODO: Write your solution here

# %% [markdown]
# ### Q42. Percentile-based analysis
# Identify top 20% by marks; compare attendance vs rest; write observations.

# %%
# TODO: Write your solution here

# %% [markdown]
# ## 15. Insight & Interpretation

# %% [markdown]
# ### Q43. Insight generation
# Write trends, risks, and interventions based on your computed outputs.

# %%
# TODO: Write your solution here
