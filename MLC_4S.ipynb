# %% [markdown]
# Recap:
#
#   --------------------------------------------------
#
#   Machine learning for cybersecurity
#
#   Applications of Machine learning
#
#   Cyber
#
#   Security
#
#   Cybersecurity
#
#   Application of Machine learning in cyberecurity
#
#   ---------------------------------------------------
#
#   Data
#
#   Question
#
#   Information
#
#   Interpretation
#
#   Knowledge
#
#   Decision
#
#   ----------------------------------------------------
#   Types of Data Analytics
#
#    Describe
#    Diagnostic
#    Prescriptive
#    predictive
#
#   ----------------------------------------------------
#
#   Life cycle of Data Analytics
#
#     context
#     problem
#     collect data
#     clean
#     EDA
#     Model
#     Visualize
#     Decision

# %% [markdown]
# Types of Data
#
#           Structure
#           Value
#           Source
#           Time
#           State
#           Security relavance

# %% [markdown]
#   Activity:
#
#     Identify the structure of the data

# %% [markdown]
# File 1: student_marks.csv

# %% [markdown]
#     Student_ID,Name,Department,Marks
#     101,Asha,CSE,78
#     102,Rahul,CSE,65
#     103,Meena,ECE,82
#     104,Arjun,EEE,49
#     105,Priya,CSE,91

# %% [markdown]
# firewall.json

# %% [markdown]
#     {
#       "timestamp": "2026-01-01T10:15:22",
#       "source_ip": "192.168.1.10",
#       "destination_ip": "10.0.0.5",
#       "protocol": "TCP",
#       "action": "ALLOW"
#     },
#     {
#       "timestamp": "2026-01-01T10:16:05",
#       "source_ip": "192.168.1.20",
#       "destination_ip": "10.0.0.8",
#       "protocol": "UDP",
#       "action": "BLOCK",
#       "reason": "Port scan detected"
#    }

# %% [markdown]
# email.txt
#
#
#     Dear User,
#
#     Your account has been temporarily suspended due to suspicious login activity.
#     Please verify your identity by clicking the link below.
#
#     Regards,
#     Security Team

# %% [markdown]
# api_response.xml
#
#     <response>
#     <user>
#     <id>501</id>
#     <name>Karthik</name>
#     <role>Admin</role>
#     </user>
#     <login>
#     <status>Success</status>
#     <time>2026-01-01T11:00:00</time>
#     </login>
#     </response>

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# Lab Activities

# %% [markdown]
#  Activity 1:
#
#  Load data with different file formats

# %% [markdown]
# Activity 2:
#
# understanding the data

# %% [markdown]
# Activity 3:
#
# writing into files

# %% [markdown]
# Cybersecurity-focused formats:
#
# CSV (NSL-KDD, CICIDS datasets)
#
# JSON (Suricata, Zeek logs)
#
# LOG files (auth.log, firewall.log)
